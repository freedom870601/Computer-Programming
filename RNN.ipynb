# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.datasets import imdb

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=20000)

# %%
x_train = sequence.pad_sequences(x_train, maxlen=100)
x_test = sequence.pad_sequences(x_test, maxlen=100)

# %%
model = Sequential()

# %%
model.add(Embedding(20000, 128))

# %%
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2, kernel_initializer = 'orthogonal'))
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 128)         2560000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,691,713
# Trainable params: 2,691,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 78s 399ms/step - loss: 0.3337 - accuracy: 0.8576 - val_loss: 0.3384 - val_accuracy: 0.8532
# Epoch 2/10
# 196/196 [==============================] - 76s 390ms/step - loss: 0.2142 - accuracy: 0.9173 - val_loss: 0.3690 - val_accuracy: 0.8456
# Epoch 3/10
# 196/196 [==============================] - 76s 390ms/step - loss: 0.1423 - accuracy: 0.9495 - val_loss: 0.5026 - val_accuracy: 0.8305
# Epoch 4/10
# 196/196 [==============================] - 76s 387ms/step - loss: 0.0918 - accuracy: 0.9682 - val_loss: 0.4871 - val_accuracy: 0.8302
# Epoch 5/10
# 196/196 [==============================] - 76s 388ms/step - loss: 0.0707 - accuracy: 0.9747 - val_loss: 0.5535 - val_accuracy: 0.8281
# Epoch 6/10
# 196/196 [==============================] - 76s 385ms/step - loss: 0.0621 - accuracy: 0.9794 - val_loss: 0.6553 - val_accuracy: 0.8256
# Epoch 7/10
# 196/196 [==============================] - 75s 380ms/step - loss: 0.0452 - accuracy: 0.9856 - val_loss: 0.6973 - val_accuracy: 0.8285
# Epoch 8/10
# 196/196 [==============================] - 75s 383ms/step - loss: 0.0351 - accuracy: 0.9885 - val_loss: 0.6575 - val_accuracy: 0.8234
# Epoch 9/10
# 196/196 [==============================] - 75s 382ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.8725 - val_accuracy: 0.8210
# Epoch 10/10
# 196/196 [==============================] - 74s 380ms/step - loss: 0.0263 - accuracy: 0.9917 - val_loss: 0.9194 - val_accuracy: 0.8190

# %% [markdown]
# # 所做的改變
# 1. 將常用字提高到20000
# 2. LSTM層的初始矩陣改為正交矩陣
# 3. batch size改為128
