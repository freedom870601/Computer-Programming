# %% [markdown]
# # 前往https://cloud.google.com/maps-platform/ 進行API的取得（需要填帳單資訊

# %% [markdown]
# # 以下操作 主要使用Place API和Geocoding API

# %% [markdown]
# 在Console輸入 pip install -U googlemaps

# %%
import googlemaps
import pandas as pd
import time
gmaps = googlemaps.Client(key = 'AIzaSyALTWc_Mki-DtWMp7lo3gOT46DW9ZA0WcY')

# %%
cities= ["臺北市","新北市","桃園市","臺中市","臺南市","高雄市","基隆市","新竹市","嘉義市","新竹縣",
        "苗栗縣","彰化縣","南投縣","雲林縣","嘉義縣","屏東縣","宜蘭縣","花蓮縣","臺東縣","澎湖縣"]

# %% [markdown]
# places_nearby一次只會回傳20間店家資料，必須用裡面的next_page_token再去拿下一間的20間店家資料，但總共最多只能拿到60間的資料

# %%
ids = []
for city in cities:
    results = []
    # Geocoding an address
    geocode_result = gmaps.geocode(city)
    loc = geocode_result[0]['geometry']['location']
    query_result = gmaps.places_nearby(keyword="大學",location=loc, radius=100000)
    results.extend(query_result['results'])
    while query_result.get('next_page_token'):
        time.sleep(2)
        query_result = gmaps.places_nearby(page_token=query_result['next_page_token'])
        results.extend(query_result['results'])    
    print("找到以"+city+"為中心半徑100000公尺的大學數量(google mapi api上限提供60間): "+str(len(results)))
    for place in results:
        ids.append(place['place_id'])
# Out:
# 找到以臺北市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以新北市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以桃園市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以臺中市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以臺南市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以高雄市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以基隆市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以新竹市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以嘉義市為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以新竹縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以苗栗縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以彰化縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以南投縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以雲林縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以嘉義縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以屏東縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以宜蘭縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 60
# 找到以花蓮縣為中心半徑100000公尺的大學數量(google mapi api上限提供60間): 35
# ...

# %%
stores_info = []
# 去除重複id
ids = list(set(ids)) 
for id in ids:
    stores_info.append(gmaps.place(place_id=id, language='zh-TW')['result'])

# %%
output = pd.DataFrame.from_dict(stores_info)

# %%
output
# Out:
#                                     address_components  \
# 0    [{u'long_name': u'321號', u'types': [u'street_n...
# 1    [{u'long_name': u'200號', u'types': [u'street_n...
# 2    [{u'long_name': u'300號', u'types': [u'street_n...
# 3    [{u'long_name': u'100號', u'types': [u'street_n...
# 4    [{u'long_name': u'內埔鄉', u'types': [u'administr...
# 5    [{u'long_name': u'1號', u'types': [u'street_num...
# 6    [{u'long_name': u'太平區', u'types': [u'administr...
# 7    [{u'long_name': u'1樓', u'types': [u'floor'], u...
# 8    [{u'long_name': u'151-2', u'types': [u'street_...
# 9    [{u'long_name': u'261號', u'types': [u'street_n...
# 10   [{u'long_name': u'壽豐鄉', u'types': [u'administr...
# 11   [{u'long_name': u'中山區', u'types': [u'administr...
# 12   [{u'long_name': u'521號', u'types': [u'street_n...
# 13   [{u'long_name': u'32號', u'types': [u'street_nu...
# 14   [{u'long_name': u'46', u'types': [u'street_num...
# 15   [{u'long_name': u'306', u'types': [u'street_nu...
# ...

# %%
output1 = output[output['formatted_phone_number'].notnull()]

# %%
output2 = output[output['international_phone_number'].notnull()]

# %%
output2
# Out:
#                                     address_components  \
# 0    [{u'long_name': u'321號', u'types': [u'street_n...
# 1    [{u'long_name': u'200號', u'types': [u'street_n...
# 2    [{u'long_name': u'300號', u'types': [u'street_n...
# 3    [{u'long_name': u'100號', u'types': [u'street_n...
# 5    [{u'long_name': u'1號', u'types': [u'street_num...
# 6    [{u'long_name': u'太平區', u'types': [u'administr...
# 9    [{u'long_name': u'261號', u'types': [u'street_n...
# 12   [{u'long_name': u'521號', u'types': [u'street_n...
# 13   [{u'long_name': u'32號', u'types': [u'street_nu...
# 14   [{u'long_name': u'46', u'types': [u'street_num...
# 15   [{u'long_name': u'306', u'types': [u'street_nu...
# 16   [{u'long_name': u'1號', u'types': [u'street_num...
# 17   [{u'long_name': u'59號', u'types': [u'street_nu...
# 18   [{u'long_name': u'155號', u'types': [u'street_n...
# 19   [{u'long_name': u'51號', u'types': [u'street_nu...
# 20   [{u'long_name': u'666', u'types': [u'street_nu...
# ...

# %%
Bool = output2['name'].str.contains(u'大學')

# %%
output3 = output2[Bool]

# %%
output3
# Out:
#                                     address_components  \
# 0    [{u'long_name': u'321號', u'types': [u'street_n...
# 1    [{u'long_name': u'200號', u'types': [u'street_n...
# 2    [{u'long_name': u'300號', u'types': [u'street_n...
# 3    [{u'long_name': u'100號', u'types': [u'street_n...
# 5    [{u'long_name': u'1號', u'types': [u'street_num...
# 6    [{u'long_name': u'太平區', u'types': [u'administr...
# 9    [{u'long_name': u'261號', u'types': [u'street_n...
# 12   [{u'long_name': u'521號', u'types': [u'street_n...
# 13   [{u'long_name': u'32號', u'types': [u'street_nu...
# 14   [{u'long_name': u'46', u'types': [u'street_num...
# 15   [{u'long_name': u'306', u'types': [u'street_nu...
# 16   [{u'long_name': u'1號', u'types': [u'street_num...
# 17   [{u'long_name': u'59號', u'types': [u'street_nu...
# 18   [{u'long_name': u'155號', u'types': [u'street_n...
# 19   [{u'long_name': u'51號', u'types': [u'street_nu...
# 20   [{u'long_name': u'666', u'types': [u'street_nu...
# ...

# %%
Bool1 = output3['name'].str.contains(u'館')
a = [not i for i in Bool1]
output4 = output3[a]
Bool2 = output4['name'].str.contains(u'中心')
b = [not i for i in Bool2]
output5 = output4[b]
Bool3 = output5['name'].str.contains(u'學院')
c = [not i for i in Bool3]
output6 = output5[c]
Bool4 = output6['name'].str.contains(u'系')
d = [not i for i in Bool4]
output7 = output6[d]
Bool5 = output7['name'].str.contains(u'組')
e = [not i for i in Bool5]
output8 = output7[e]

# %%
output8.reset_index(drop=True, inplace=True)

# %%
output8
# Out:
#                                     address_components  \
# 0    [{u'long_name': u'321號', u'types': [u'street_n...
# 1    [{u'long_name': u'200號', u'types': [u'street_n...
# 2    [{u'long_name': u'100號', u'types': [u'street_n...
# 3    [{u'long_name': u'1號', u'types': [u'street_num...
# 4    [{u'long_name': u'261號', u'types': [u'street_n...
# 5    [{u'long_name': u'521號', u'types': [u'street_n...
# 6    [{u'long_name': u'32號', u'types': [u'street_nu...
# 7    [{u'long_name': u'46', u'types': [u'street_num...
# 8    [{u'long_name': u'306', u'types': [u'street_nu...
# 9    [{u'long_name': u'1號', u'types': [u'street_num...
# 10   [{u'long_name': u'59號', u'types': [u'street_nu...
# 11   [{u'long_name': u'155號', u'types': [u'street_n...
# 12   [{u'long_name': u'51號', u'types': [u'street_nu...
# 13   [{u'long_name': u'666', u'types': [u'street_nu...
# 14   [{u'long_name': u'118號', u'types': [u'street_n...
# 15   [{u'long_name': u'2', u'types': [u'street_numb...
# ...

# %%
geo = output8['geometry']
name = output8['name']

# %%
dlat = []
dlng = []
dname = []
for i in range (len(output8['geometry'])):
    dlat.append(geo[i]['location']['lat'])
    dlng.append(geo[i]['location']['lng'])
    dname.append(name[i])

# %% [markdown]
# # 在console輸入pip install folium

# %%
import folium
# Out:
# /Users/laiyanru/anaconda2/lib/python2.7/site-packages/folium/__init__.py:59: UserWarning: This version of folium is the last to support Python 2. Transition to Python 3 to be able to receive updates and fixes. Check out https://python3statement.org/ for more info.
#   UserWarning

# %%
world_map = folium.Map()

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latitude = 23.973875
longitude = 120.982024
taiwan_map = folium.Map(location=[latitude, longitude], zoom_start=7,tiles='Cartodb Positron')

# %%
taiwan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Instantiate a feature group for the incidents in the dataframe
incidents = folium.map.FeatureGroup()

# Loop through the 200 crimes and add each to the incidents feature group
for lat, lng, in zip(dlat, dlng):
    incidents.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=7, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red',
            fill_opacity=0.4
        )
    )

# Add incidents to map
taiwan_map = folium.Map(location=[latitude, longitude], zoom_start=7,tiles='Cartodb Positron')
taiwan_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add pop-up text to each marker on the map

for lat, lng, label in zip(dlat, dlng, dname):
    folium.Marker([lat, lng], popup=label).add_to(taiwan_map)    
    
# add incidents to map
taiwan_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins

# let's start again with a clean copy of the map 
taiwan_map = folium.Map(location = [latitude, longitude], zoom_start = 7,tiles='Cartodb Positron')

# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(nccu_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(dlat, dlng, dname):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# add incidents to map
taiwan_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
